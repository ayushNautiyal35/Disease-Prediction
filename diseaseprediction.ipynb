# %%
from tkinter import *

# %%
# header files for disease prediction
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import tree
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
from sklearn.preprocessing import OneHotEncoder
import os
from PIL import ImageTk,Image
from tkinter import messagebox
from tkinter import filedialog

# %%
#function for heart disease
p2=0.00
p5=0.00
p7=0.00
def hd():
    #for new window
    top= Toplevel()

    def myclick():
        #for pain
        global p2
        if(clicked.get()=='Select'):
            messagebox.showinfo("Error",'Please select any value')
        if(clicked.get()=='Severe pain in heart' ):
            p2=0.00
        if(clicked.get()== " Feeling fatigue or sleep disturbances or shortness of breath"):
            p2=1.00
        if(clicked.get()==" Feeling recurring pain behind breast bone and near heart"):
            p2=2.00
        if(clicked.get()==" No pain"):
            p2=3.00
    
        #for fasting bs
        global p5
        if(clicked1.get()=='Yes'):
            p5=1.00
        else:
            p5=0.00
 
        
        # for exercise angina
        global p7
        if(clicked2.get()=='Yes'):
            p7=1.00
        else:
            p7=0.00
            
        input_data=(p1.get(),p2,p3.get(),p4.get(),p5,p6.get(),p7)

        array=np.asarray(input_data,dtype=int)
      
        #reshape the array as we are predicting for only one instance
        input_data_reshaped=array.reshape(1,-1)
        prediction = model.predict(input_data_reshaped)

        if(prediction==1):
            ls=Label(top,text="You have the heart disease")
            ls.configure(bg='white',fg='red')
        else:
            ls=Label(top,text="You are healthy")
            ls.configure(bg='white',fg='blue')
        ls.pack()
    
    #for using the input
    l=Label(top,text="enter age :")
    l.configure(bg='black',fg='white')
    e=Entry(top,width=50)
    p1=e
    l.pack()
    e.pack()
    
    
    #for drop down menu
    #for default value in the dropdown box
    clicked=StringVar()
    clicked.set("Select")
    l=Label(top,text="enter level of Chest pain :")
    l.configure(bg='black',fg='white')
    options={"Severe pain in heart  ",
             " Feeling fatigue or sleep disturbances or shortness of breath",
             " Feeling recurring pain behind breast bone and near heart",
             " No pain"}
    drop=OptionMenu(top,clicked,*options)
    l.pack()
    drop.pack()
    
    
    l=Label(top,text="enter resting bp :")
    l.configure(bg='black',fg='white')
    e=Entry(top,width=50)
    p3=e
    l.pack()
    e.pack()        
            

    l=Label(top,text="enter cholestrol :")
    l.configure(bg='black',fg='white')
    e=Entry(top,width=50)
    p4=e
    l.pack()
    e.pack()
    
    clicked1=StringVar()
    clicked1.set("No")
    l=Label(top,text="Is Fasting Blood Sugar greater than 120")
    l.configure(bg='black',fg='white')
    options1={"Yes","No"}
    drop=OptionMenu(top,clicked1,*options1)
    l.pack()
    drop.pack()
    
    l=Label(top,text="enter maximum heart rate reached :")
    l.configure(bg='black',fg='white')
    e=Entry(top,width=50)
    p6=e
    l.pack()
    e.pack()
    
    
    l=Label(top,text="do you have exercise angina\n(heaviness or pain in the chest) :")
    l.configure(bg='black',fg='white')
    clicked2=StringVar()
    clicked2.set("No")
    options2={"Yes","No"}
    drop=OptionMenu(top,clicked2,*options2)
    l.pack()
    drop.pack()
    
    
   
  
    
    mybutton=Button(top,text="Submit",command=myclick)
    mybutton.configure(bg='grey')
    mybutton.pack()
    button_exit= Button(top,text='Return to main menu',command=top.destroy)
    button_exit.configure(bg='red',fg='black')
    button_exit.pack()
    
  
    

    
    
    # for reading data
    heart=pd.read_csv("heart.csv")
    a={'Y':1,'N':0}
    heart.ExerciseAngina = [a[item] for item in heart.ExerciseAngina]
    b={'TA':0,'ATA':1,'NAP':2,'ASY':3}
    heart.ChestPainType= [b[item] for item in heart.ChestPainType]
   

    #1-> heart problem
    #0-> heart healthy
    x=heart.drop(columns='HeartDisease',axis=1)
    y=heart['HeartDisease']    
    #splitting the data into training and test data set
    x_train,x_test,y_train,y_test=train_test_split(x,y)
    
    #logistic regresssion
    model=LogisticRegression()
    
    model.fit(x_train,y_train)

# %%
#function for common disease

def cd():
    #for new window
    top= Toplevel()
    #Reading the training .csv file
    df=pd.read_csv("training.csv")
    DF= pd.read_csv('training.csv', index_col='prognosis')
    
    l1=['back_pain','constipation','abdominal_pain','diarrhoea','mild_fever','yellow_urine',
        'yellowing_of_eyes','acute_liver_failure','fluid_overload','swelling_of_stomach',
        'swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
        'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs',
        'fast_heart_rate','pain_during_bowel_movements','pain_in_anal_region','bloody_stool',
        'irritation_in_anus','neck_pain','dizziness','cramps','bruising','obesity','swollen_legs',
        'swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
        'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips',
        'slurred_speech','knee_pain','hip_joint_pain','muscle_weakness','stiff_neck','swelling_joints',
        'movement_stiffness','spinning_movements','loss_of_balance','unsteadiness',
        'weakness_of_one_body_side','loss_of_smell','bladder_discomfort','foul_smell_of urine',
        'continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
        'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain',
        'abnormal_menstruation','dischromic _patches','watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum',
        'rusty_sputum','lack_of_concentration','visual_disturbances','receiving_blood_transfusion',
        'receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen',
        'history_of_alcohol_consumption','fluid_overload','blood_in_sputum','prominent_veins_on_calf',
        'palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
        'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose',
        'yellow_crust_ooze']
    l2=[]
    for i in range(0,len(l1)):
        l2.append(0)

   

    #List of Diseases is listed in list disease.

    disease=['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
             'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes ',
             'Gastroenteritis', 'Bronchial Asthma', 'Hypertension ', 'Migraine',
             'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
             'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
             'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
             'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
             'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
             'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
             'Osteoarthristis', 'Arthritis',
             '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
             'Urinary tract infection', 'Psoriasis', 'Impetigo']

    #Replace the values in the imported file by pandas by the inbuilt function replace in pandas.

    df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
                             'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
                             'Migraine':11,'Cervical spondylosis':12,
                             'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
                             'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
                             'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
                             'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
                             '(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
                             'Impetigo':40}},inplace=True)
    X= df[l1]
    y = df[["prognosis"]]
    #used to change a 2-dimensional array or a multi-dimensional array into a contiguous flattened array
    np.ravel(y)
   
    #Reading the  testing.csv file
    tr=pd.read_csv("testing.csv")

    
    #Using inbuilt function replace in pandas for replacing the values

    tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
                             'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
                             'Migraine':11,'Cervical spondylosis':12,
                             'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
                             'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
                             'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
                             'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
                             '(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
                             'Impetigo':40}},inplace=True)
    X_test= tr[l1]
    y_test = tr[["prognosis"]]
    np.ravel(y_test)
    
    
    def dt():
        if((took1.get()=="None") or (took2.get()=="None")):
            messagebox.showinfo("Error",'Please select at least two symptoms')
        
        

        clf3 = tree.DecisionTreeClassifier() 
        clf3 = clf3.fit(X,y)
        y_pred=clf3.predict(X_test)


        psymptoms = [took1.get(),took2.get(),took3.get(),took4.get(),took5.get()]

        for k in range(0,len(l1)):
            for z in psymptoms:
                if(z==l1[k]):
                    l2[k]=1
                    
                

        inputtest = [l2]
        predict = clf3.predict(inputtest)
        predicted=predict[0]

        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break

    
        if (h=='yes'):
            l=Label(top,text=disease[predicted])
            l.configure(bg='white',fg='red')
        else:
             l=Label(top,text="Healthy Body")
             l.configure(bg='white',fg='blue')
        l.pack()        
           
    
    
    #for the window
    
    la1=Label(top,text="Symptoms 1:")
    la1.configure(bg='black',fg='white')
    took1=StringVar()
    took1.set("None")
    drop=OptionMenu(top,took1,*l1)
    la1.pack()
    drop.pack()
    
    la2=Label(top,text="Symptoms 2:")
    la2.configure(bg='black',fg='white')
    took2=StringVar()
    took2.set("None")
    drop=OptionMenu(top,took2,*l1)
    la2.pack()
    drop.pack()
    
    la3=Label(top,text="Symptoms 3:")
    la3.configure(bg='black',fg='white')
    took3=StringVar()
    took3.set("None")
    drop=OptionMenu(top,took3,*l1)
    la3.pack()
    drop.pack()
    
    la4=Label(top,text="Symptoms 4:")
    la4.configure(bg='black',fg='white')
    took4=StringVar()
    took4.set("None")
    drop=OptionMenu(top,took4,*l1)
    la4.pack()
    drop.pack()
   
    la5=Label(top,text="Symptoms 5:")
    la5.configure(bg='black',fg='white')
    took5=StringVar()
    took5.set("None")
    drop=OptionMenu(top,took5,*l1)
    la5.pack()
    drop.pack()
   
    
    mybutton=Button(top,text="Submit",command=dt)
    mybutton.configure(bg='grey')
    mybutton.pack()
    button_exit= Button(top,text='Return to main menu',command=top.destroy)
    button_exit.configure(bg='red',fg='black')
    button_exit.pack()

# %%
 df=pd.read_csv("corona_test.csv")

# %%
#to change NA values
df.age_60_and_above =df.age_60_and_above.fillna('No')
df.gender=df.gender.fillna("male")

# %%
#for changing the value of the strings
a={'negative':0,'positive':1,'other':2}
df.corona_result = [a[item] for item in df.corona_result]

# %%
b={'No':0,'Yes':1}
df.age_60_and_above = [b[item] for item in df.age_60_and_above]

# %%
c={'male':0,'female':1,'other':2}
df.gender = [c[item] for item in df.gender ]

# %%
d={'Other':0,'Abroad':1,'Contact with confirmed':2}
df.test_indication = [d[item] for item in df.test_indication ]

# %%
x=df.drop(columns='corona_result',axis=1)
y=df['corona_result']
    
#splitting the data into training and test data set
x_train,x_test,y_train,y_test=train_test_split(x,y)
    
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#function for the covid 19
p1=0.00
p2=0.00
p3=0.00
p4=0.00
p5=0.00
p6=0.00
p7=0.00
p8=0.00

def co():
    
    top= Toplevel()
    
   
   
    #function for my selct
    def myselect():
         
        global p1
        if(put1.get()=='Yes' ):
            p1=1.00
        else:
            p1=0.00
        global p2
        if(put2.get()=='Yes' ):
            p2=1.00
        else:
            p2=0.00
        
        global p3
        if(put3.get()=='Yes' ):
            p3=1.00
        else:
            p3=0.00
        
        global p4
        if(put4.get()=='Yes' ):
            p4=1.00
        else:
            p4=0.00
        
        global p5
        if(put5.get()=='Yes' ):
            p5=1.00
        else:
            p5=0.00
        
        global p6
        if(put6.get()=='Yes' ):
            p6=1.00
        else:
            p6=0.00
        
        global p7
        if(put7.get()=='Male' ):
            p7=0.00
        if(put7.get()=='Female' ):
            p7=1.00
        if(put7.get()=='Other' ):
            p7=2.00
        global p8
        if(put8.get()=='Other' ):
            p8=0.00
        if(put8.get()=='Abroad' ):
            p8=1.00
        if(put8.get()=='Contact with confirmed' ):
            p8=2.00
        
        
             
        input_data=(p1,p2,p3,p4,p5,p6,p7,p8)

        array=np.asarray(input_data,dtype=int)
      
        input_data_reshaped=array.reshape(1,-1)
        prediction = model.predict(input_data_reshaped)

        if(prediction==1):
            l=Label(top,text="Covid Positive")
            l.configure(bg='white',fg='red')
        
        else:
            l=Label(top,text="Covid Negative")
            l.configure(bg='white',fg='blue')
        l.pack()


        
        
        
    
    #for window content
    l1=Label(top,text="Are you suffering from cough")
    l1.configure(bg='black',fg='white')
    put1=StringVar()
    put1.set("No")
    option1={"Yes","No"}
    drop=OptionMenu(top,put1,*option1)
    l1.pack()
    drop.pack()
    
    l2=Label(top,text="Are you suffering from fever")
    l2.configure(bg='black',fg='white')
    put2=StringVar()
    put2.set("No")
    option2={"Yes","No"}
    drop=OptionMenu(top,put2,*option2)
    l2.pack()
    drop.pack()
    
    l3=Label(top,text="Are you suffering from sore throat")
    l3.configure(bg='black',fg='white')
    put3=StringVar()
    put3.set("No")
    option3={"Yes","No"}
    drop=OptionMenu(top,put3,*option3)
    l3.pack()
    drop.pack()
    
    l4=Label(top,text="Are you suffering from shortness of breath")
    l4.configure(bg='black',fg='white')
    put4=StringVar()
    put4.set("No")
    option4={"Yes","No"}
    drop=OptionMenu(top,put4,*option4)
    l4.pack()
    drop.pack()
    
    l5=Label(top,text="Are you suffering from headache")
    l5.configure(bg='black',fg='white')
    put5=StringVar()
    put5.set("No")
    option5={"Yes","No"}
    drop=OptionMenu(top,put5,*option5)
    l5.pack()
    drop.pack()
    
    l6=Label(top,text="Are you above 60")
    l6.configure(bg='black',fg='white')
    put6=StringVar()
    put6.set("No")
    option6={"Yes","No"}
    drop=OptionMenu(top,put6,*option6)
    l6.pack()
    drop.pack()
    
    l7=Label(top,text="Gender:")
    l7.configure(bg='black',fg='white')
    put7=StringVar()
    put7.set("Male")
    option7={"Male","Female","Other"}
    drop=OptionMenu(top,put7,*option7)
    l7.pack()
    drop.pack()
    
    l8=Label(top,text="What are the test indication")
    l8.configure(bg='black',fg='white')
    put8=StringVar()
    put8.set("Other")
    option8={"Other","Abroad","Contactwith confirmed"}
    drop=OptionMenu(top,put8,*option8)
    l8.pack()
    drop.pack()
    
    top.configure(bg='white')
    mybutton=Button(top,text="Submit",command=myselect)
    mybutton.configure(bg='grey')
    mybutton.pack()
    button_exit= Button(top,text='Return to main menu',command=top.destroy)
    button_exit.configure(bg='red',fg='black')
    button_exit.pack()

# %%
#file loading for brain tumor
# 0 - Tumor
# 1 - Normal
encoder = OneHotEncoder()
encoder.fit([[0], [1]])

data = []
paths = []
result = []

for r, d, f in os.walk('yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())
paths = []
for r, d, f in os.walk("no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())
data = np.array(data)
data.shape
result = np.array(result)
result = result.reshape(139,2)
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))
model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
y_train.shape
history= model.fit(x_train, y_train, epochs = 25, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/25
# 3/3 [==============================] - 25s 6s/step - loss: 19.0081 - val_loss: 22.5331
# Epoch 2/25
# 3/3 [==============================] - 17s 6s/step - loss: 10.5870 - val_loss: 36.7978
# Epoch 3/25
# 3/3 [==============================] - 17s 6s/step - loss: 3.7847 - val_loss: 18.0034
# Epoch 4/25
# 3/3 [==============================] - 17s 6s/step - loss: 1.9625 - val_loss: 22.2525
# Epoch 5/25
# 3/3 [==============================] - 17s 6s/step - loss: 2.0280 - val_loss: 22.1030
# Epoch 6/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.8726 - val_loss: 20.7528
# Epoch 7/25
# 3/3 [==============================] - 17s 6s/step - loss: 1.0993 - val_loss: 21.4960
# Epoch 8/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.4005 - val_loss: 18.4401
# Epoch 9/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.0967 - val_loss: 14.5340
# Epoch 10/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.3124 - val_loss: 12.0152
# Epoch 11/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.2513 - val_loss: 9.4546
# Epoch 12/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.2021 - val_loss: 8.5859
# Epoch 13/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.0536 - val_loss: 7.6554
# Epoch 14/25
# 3/3 [==============================] - 19s 6s/step - loss: 0.0624 - val_loss: 6.8733
# Epoch 15/25
# 3/3 [==============================] - 18s 6s/step - loss: 0.1258 - val_loss: 7.3625
# Epoch 16/25
# 3/3 [==============================] - 18s 6s/step - loss: 0.0013 - val_loss: 7.6853
# Epoch 17/25
# 3/3 [==============================] - 18s 6s/step - loss: 0.0014 - val_loss: 7.8334
# Epoch 18/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.2063 - val_loss: 7.9880
# Epoch 19/25
# 3/3 [==============================] - 18s 6s/step - loss: 0.0953 - val_loss: 7.9543
# Epoch 20/25
# 3/3 [==============================] - 17s 6s/step - loss: 7.9682e-04 - val_loss: 7.8872
# Epoch 21/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.0269 - val_loss: 7.9133
# Epoch 22/25
# 3/3 [==============================] - 18s 6s/step - loss: 0.0673 - val_loss: 8.5597
# Epoch 23/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.0330 - val_loss: 9.5253
# Epoch 24/25
# 3/3 [==============================] - 17s 6s/step - loss: 0.2944 - val_loss: 8.4032
# Epoch 25/25
# 3/3 [==============================] - 20s 6s/step - loss: 5.7670e-07 - val_loss: 7.0456

# %%
#function for brain tumor
def br():
    top=Toplevel()
    def names(number):
        if number==0:
            return 'Its a Tumor'
        else:
            return 'No, Its not a tumor'
    

    top.filename=filedialog.askopenfilename(initialdir="C:/Users/ayush nautiyal/Pictures",title="Select a file",filetypes=(("jpeg flies","*.jpg"),("all files","*.")))
    
    from matplotlib.pyplot import imshow
    img = Image.open(top.filename)
    x = np.array(img.resize((128,128)))
    x = x.reshape(1,128,128,3)
    res = model.predict_on_batch(x)
    classification = np.where(res == np.amax(res))[1][0]
    frame=Frame(top,width=400,height=400)
   
    l2=Label(top,text=str(res[0][classification]*100) + '% Confidence  ' + names(classification))
    l2.configure(bg='black',fg='white')
    l2.pack()

# %%
#main function for the code

root=Tk()
root.title('Disease prediction- By Ayush Nautiyal')
root.iconbitmap("favicon.ico")
root.geometry('400x400')

#for the color option wher bg for background,fg for fore ground, active background and foreground when mouse is placed on it
def callfunc(name,index,mode):
    if(clicked.get()=='Heart Disease'):
        drop.config(bg='black',fg='red',activebackground="white",activeforeground='blue')
    if(clicked.get()=='Common Disease'):
        drop.config(bg='black',fg='white',activebackground="white",activeforeground='blue')
    if(clicked.get()=='Covid 19'):
        drop.config(bg='black',fg='yellow',activebackground="white",activeforeground='blue')
    if(clicked.get()=='Brain tumor'):
        drop.config(bg='black',fg='green',activebackground="white",activeforeground='blue')


#for function show which get the value in the dropbox we select

def show():
    if(clicked.get()=='Select'):
        messagebox.showinfo("Error",'Please select any value')
    if(clicked.get()=='Heart Disease'):
        hd()
    if(clicked.get()=='Common Disease'):
        cd()
    if(clicked.get()=='Covid 19'):
        co()
    if(clicked.get()=='Brain tumor'):
        br()

    
        
#options we gonna show in the dropbox         
options={
    "Heart Disease",
    "Common Disease",
    "Covid 19",
    "Brain tumor"
}

# for adding images
my_img=ImageTk.PhotoImage(Image.open("image.jpg"))
img=Label(image=my_img).pack()

#for default value in the dropdown box
clicked=StringVar()
clicked.set("Select")

#for drop down menu
drop=OptionMenu(root,clicked,*options)
drop.pack()

#for changing the color in the dropdown menu
Call=clicked.trace_variable('w',callfunc)
mybutton=Button(root,text="Submit",command=show)
mybutton.configure(bg='grey',fg='black')
mybutton.pack()

#for exit button
button_exit= Button(root,text='Exit',command=root.destroy)
button_exit.configure(bg='red',fg='black')
button_exit.pack()

# for color 
root.configure(bg='white')

#the looop will run until exit not pressed
root.mainloop()
